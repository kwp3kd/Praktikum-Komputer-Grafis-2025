# %% [markdown]
# <a href="https://colab.research.google.com/github/kwp3kd/Praktikum-Komputer-Grafis-2025/blob/main/Implementasi_Teknik_Operasi_Pada_Citra_G211240045_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61b9d516-5459-42c3-872b-43493722529b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61b9d516-5459-42c3-872b-43493722529b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Resizing 0.5

img = cv2.imread('TaylorSwift.JPG')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img3 = cv2.resize(img2, None, fx=0.5, fy=0.5, interpolation = cv2.INTER_CUBIC)
plt.imshow(img3)

# %%
# Rotation 90
rows,cols,ch = img2.shape
M = cv2.getRotationMatrix2D((cols/2,rows/2), 90, 1)
dst = cv2.warpAffine(img2, M, (cols, rows))
plt.imshow(dst)

# %%
# Affline transformation
rows,cols,ch = img2.shape
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])
M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img2,M,(cols,rows))
plt.imshow(dst)

# %%
 # Perspective transform
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300], [300,300]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img2,M,(300,300))
plt.imshow(dst)
